# %%
import sys
import gensim, logging

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# ## Сначала мы определимся с моделями:
# - model1 - модель, которую мы натренировали на корпусе из рецензий на рестораны;
# - model2 - модель НКРЯ с сайта русвекторес;
# - model3 - НКРЯ и Википедия оттуда же;
# - model4 - веб-корпус оттуда же;
# - model5 - новостной корпус оттуда же.

# %%
f = 'corpora.txt'
data = gensim.models.word2vec.LineSentence(f)

# %%
model1 = gensim.models.Word2Vec(data, size=500, window=10, min_count=2, sg=0)
# Out:
# 2017-03-21 20:11:36,343 : INFO : collecting all words and their counts
# 2017-03-21 20:11:36,349 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-03-21 20:11:36,375 : INFO : collected 4087 word types from a corpus of 16428 raw words and 1332 sentences
# 2017-03-21 20:11:36,376 : INFO : Loading a fresh vocabulary
# 2017-03-21 20:11:36,387 : INFO : min_count=2 retains 1531 unique words (37% of original 4087, drops 2556)
# 2017-03-21 20:11:36,390 : INFO : min_count=2 leaves 13872 word corpus (84% of original 16428, drops 2556)
# 2017-03-21 20:11:36,400 : INFO : deleting the raw counts dictionary of 4087 items
# 2017-03-21 20:11:36,402 : INFO : sample=0.001 downsamples 60 most-common words
# 2017-03-21 20:11:36,404 : INFO : downsampling leaves estimated 10518 word corpus (75.8% of prior 13872)
# 2017-03-21 20:11:36,406 : INFO : estimated required memory for 1531 words and 500 dimensions: 6889500 bytes
# ...

# %%
model1.init_sims(replace=True)
# Out:
# 2017-03-21 20:11:55,165 : INFO : precomputing L2-norms of word weight vectors

# %%
print(len(model1.wv.vocab))
# Out:
# 1531

# %%
for word in words:
    # есть ли слово в модели? Может быть, и нет
    if word in model1:
        print(word)
        # выдаем 10 ближайших соседей слова:
        for i in model1.most_similar(positive=[word], topn=20):
            # слово + коэффициент косинусной близости
            print(i[0], i[1])
        print('\n')
    else:
        # Увы!
        print(word + ' is not present in the model')
# мне не нравится, пробую другую модель
# Out:
# хороший_ADJF
# и_CONJ 0.9999631643295288
# не_PRCL 0.9999623894691467
# в_PREP 0.9999623894691467
# с_PREP 0.9999604225158691
# я_NPRO 0.9999600648880005
# что_CONJ 0.9999569654464722
# на_PREP 0.9999565482139587
# быть_VERB 0.999956488609314
# а_CONJ 0.9999556541442871
# весь_ADJF 0.9999551773071289
# но_CONJ 0.9999550580978394
# по_PREP 0.9999545812606812
# мы_NPRO 0.9999536275863647
# очень_ADVB 0.99995356798172
# к_PREP 0.9999529719352722
# то_CONJ 0.9999524354934692
# для_PREP 0.9999520778656006
# из_PREP 0.9999514818191528
# это_PRCL 0.9999499320983887
# ещё_PRCL 0.9999496936798096
#
#
# плохой_ADJF
# а_CONJ 0.9971604943275452
# бы_PRCL 0.9971535205841064
# и_CONJ 0.9971534609794617
# мы_NPRO 0.9971478581428528
# тот_ADJF 0.997144877910614
# для_PREP 0.9971438646316528
# человек_NOUN 0.9971414804458618
# очень_ADVB 0.9971394538879395
# только_PRCL 0.9971386790275574
# просто_PRCL 0.9971370100975037
# как_CONJ 0.9971368312835693
# так_CONJ 0.9971358776092529
# ...

# %%
m = 'ruscorpora_1_300_10.bin'
model2 = gensim.models.KeyedVectors.load_word2vec_format(m, binary=True)
# Out:
# 2017-03-21 20:13:05,183 : INFO : loading projection weights from ruscorpora_1_300_10.bin
# 2017-03-21 20:13:09,708 : INFO : loaded (184973, 300) matrix from ruscorpora_1_300_10.bin

# %%
model2.init_sims(replace=True)
# Out:
# 2017-03-21 20:37:37,143 : INFO : precomputing L2-norms of word weight vectors

# %%
words = ['хороший_ADJ', 'плохой_ADJ', 'вкусный_ADJ', 'ужасный_ADJ', 
         'худший_ADJ', 'замечательный_ADJ', 'неприятный_ADJ', 'приятный_ADJ', 'красивый_ADJ', 'отличный_ADJ']

# %%
for word in words:
    # есть ли слово в модели? Может быть, и нет
    if word in model2:
        print(word)
        # выдаем 10 ближайших соседей слова:
        for i in model2.most_similar(positive=[word], topn=20):
            # слово + коэффициент косинусной близости
            print(i[0], i[1])
        print('\n')
    else:
        # Увы!
        print(word + ' is not present in the model')
# Out:
# хороший_ADJ
# плохой_ADJ 0.7462217211723328
# неплохой_ADJ 0.6795690059661865
# отличный_ADJ 0.6773216724395752
# превосходный_ADJ 0.6319643259048462
# прекрасный_ADJ 0.5960804224014282
# недурной_ADJ 0.5627024173736572
# дурной_ADJ 0.5577998161315918
# замечательный_ADJ 0.538101851940155
# сносный_ADJ 0.5372092127799988
# хорошо_ADV 0.5181484222412109
# отменный_ADJ 0.510392427444458
# скверный_ADJ 0.502884030342102
# приличный_ADJ 0.5002855658531189
# посредственный_ADJ 0.49339690804481506
# добрый_ADJ 0.4857481122016907
# порядочный_ADJ 0.48426640033721924
# великолепный_ADJ 0.483857125043869
# достойный_ADJ 0.4766625761985779
# ддда_NOUN 0.47260409593582153
# нюрашка_NOUN 0.4678889214992523
#
#
# плохой_ADJ
# хороший_ADJ 0.7462217211723328
# плохо_ADV 0.6979023218154907
# дурной_ADJ 0.6594477891921997
# скверный_ADJ 0.6073296070098877
# неплохой_ADJ 0.5692754983901978
# никудышный_ADJ 0.5689748525619507
# неважный_ADJ 0.5533224940299988
# нехороший_ADJ 0.5417060852050781
# ...

# %%
# давайте попробую поставить ограничение на чр
for word in words:
    # есть ли слово в модели? Может быть, и нет
    if word in model2:
        print(word)
        # выдаем 10 ближайших соседей слова:
        for i in model2.most_similar(positive=[word], topn=20):
            # слово + коэффициент косинусной близости
            if i[0].endswith('_ADJ'):
                print(i[0], i[1])
        print('\n')
    else:
        # Увы!
        print(word + ' is not present in the model')
# Out:
# хороший_ADJ
# плохой_ADJ 0.7462217211723328
# неплохой_ADJ 0.6795690059661865
# отличный_ADJ 0.6773216724395752
# превосходный_ADJ 0.6319643259048462
# прекрасный_ADJ 0.5960804224014282
# недурной_ADJ 0.5627024173736572
# дурной_ADJ 0.5577998161315918
# замечательный_ADJ 0.538101851940155
# сносный_ADJ 0.5372092127799988
# отменный_ADJ 0.510392427444458
# скверный_ADJ 0.502884030342102
# приличный_ADJ 0.5002855658531189
# посредственный_ADJ 0.49339690804481506
# добрый_ADJ 0.4857481122016907
# порядочный_ADJ 0.48426640033721924
# великолепный_ADJ 0.483857125043869
# достойный_ADJ 0.4766625761985779
#
#
# плохой_ADJ
# хороший_ADJ 0.7462217211723328
# дурной_ADJ 0.6594477891921997
# скверный_ADJ 0.6073296070098877
# неплохой_ADJ 0.5692754983901978
# никудышный_ADJ 0.5689748525619507
# неважный_ADJ 0.5533224940299988
# нехороший_ADJ 0.5417060852050781
# отличный_ADJ 0.5040527582168579
# хужий_ADJ 0.49492624402046204
# посредственный_ADJ 0.4907936155796051
# ...

# %%
m = 'ruwikiruscorpora_0_300_20.bin'
model3 = gensim.models.KeyedVectors.load_word2vec_format(m, binary=True)
# Out:
# 2017-03-21 20:46:01,483 : INFO : loading projection weights from ruwikiruscorpora_0_300_20.bin
# 2017-03-21 20:46:11,362 : INFO : loaded (392339, 300) matrix from ruwikiruscorpora_0_300_20.bin

# %%
model3.init_sims(replace=True)
# Out:
# 2017-03-21 20:46:29,592 : INFO : precomputing L2-norms of word weight vectors

# %%
for word in words:
    # есть ли слово в модели? Может быть, и нет
    if word in model3:
        print(word)
        # выдаем 10 ближайших соседей слова:
        for i in model3.most_similar(positive=[word], topn=20):
            # слово + коэффициент косинусной близости
            print(i[0], i[1])
        print('\n')
    else:
        # Увы!
        print(word + ' is not present in the model')
# Out:
# хороший_ADJ
# отличный_ADJ 0.6811167001724243
# неплохой_ADJ 0.640072226524353
# плохой_ADJ 0.6243505477905273
# превосходный_ADJ 0.6026121377944946
# посредственный_ADJ 0.5559852123260498
# первоклассный_ADJ 0.5114709734916687
# отменный_ADJ 0.4981483817100525
# достойный_ADJ 0.4923921227455139
# удачный_ADJ 0.48826849460601807
# приличный_ADJ 0.47672000527381897
# завидный_ADJ 0.4551009237766266
# замечательный_ADJ 0.44932305812835693
# престижный_ADJ 0.44749000668525696
# прекрасный_ADJ 0.43856608867645264
# заслуженно_ADV 0.43818339705467224
# стильный_ADJ 0.43298906087875366
# многообещающий_ADJ 0.43266206979751587
# непревзойденный_ADJ 0.4318729639053345
# талантливый_ADJ 0.4305424690246582
# великолепный_ADJ 0.42835476994514465
#
#
# плохой_ADJ
# плохо_ADV 0.6465858817100525
# дурной_ADJ 0.6440732479095459
# хороший_ADJ 0.6243506669998169
# скверный_ADJ 0.6127551794052124
# посредственный_ADJ 0.5784285068511963
# неудовлетворительный_ADJ 0.5223508477210999
# ...

# %%
# давайте попробую поставить ограничение на чр
for word in words:
    # есть ли слово в модели? Может быть, и нет
    if word in model3:
        print(word)
        # выдаем 10 ближайших соседей слова:
        for i in model3.most_similar(positive=[word], topn=20):
            # слово + коэффициент косинусной близости
            if i[0].endswith('_ADJ'):
                print(i[0], i[1])
        print('\n')
    else:
        # Увы!
        print(word + ' is not present in the model')
# Out:
# хороший_ADJ
# отличный_ADJ 0.6811167001724243
# неплохой_ADJ 0.640072226524353
# плохой_ADJ 0.6243505477905273
# превосходный_ADJ 0.6026121377944946
# посредственный_ADJ 0.5559852123260498
# первоклассный_ADJ 0.5114709734916687
# отменный_ADJ 0.4981483817100525
# достойный_ADJ 0.4923921227455139
# удачный_ADJ 0.48826849460601807
# приличный_ADJ 0.47672000527381897
# завидный_ADJ 0.4551009237766266
# замечательный_ADJ 0.44932305812835693
# престижный_ADJ 0.44749000668525696
# прекрасный_ADJ 0.43856608867645264
# стильный_ADJ 0.43298906087875366
# многообещающий_ADJ 0.43266206979751587
# непревзойденный_ADJ 0.4318729639053345
# талантливый_ADJ 0.4305424690246582
# великолепный_ADJ 0.42835476994514465
#
#
# плохой_ADJ
# дурной_ADJ 0.6440732479095459
# хороший_ADJ 0.6243506669998169
# скверный_ADJ 0.6127551794052124
# посредственный_ADJ 0.5784285068511963
# неудовлетворительный_ADJ 0.5223508477210999
# неплохой_ADJ 0.5212443470954895
# нехороший_ADJ 0.5176498889923096
# ...

# %%
m = 'web_0_300_20.bin'
model4 = gensim.models.KeyedVectors.load_word2vec_format(m, binary=True)
# Out:
# 2017-03-21 20:49:19,913 : INFO : loading projection weights from web_0_300_20.bin
# 2017-03-21 20:49:26,243 : INFO : loaded (267540, 300) matrix from web_0_300_20.bin

# %%
model4.init_sims(replace=True)
# Out:
# 2017-03-21 20:49:34,240 : INFO : precomputing L2-norms of word weight vectors

# %%
for word in words:
    # есть ли слово в модели? Может быть, и нет
    if word in model4:
        print(word)
        # выдаем 10 ближайших соседей слова:
        for i in model4.most_similar(positive=[word], topn=20):
            # слово + коэффициент косинусной близости
            print(i[0], i[1])
        print('\n')
    else:
        # Увы!
        print(word + ' is not present in the model')
# Out:
# хороший_ADJ
# отличный_ADJ 0.7432949542999268
# неплохой_ADJ 0.6367652416229248
# превосходный_ADJ 0.604561448097229
# идеальный_ADJ 0.5773133039474487
# достойный_ADJ 0.5759782791137695
# отменный_ADJ 0.5750353336334229
# замечательный_ADJ 0.5604514479637146
# плохой_ADJ 0.5595842599868774
# прекрасный_ADJ 0.556372880935669
# удачный_ADJ 0.5306262969970703
# безупречный_ADJ 0.5232981443405151
# великолепный_ADJ 0.5031687617301941
# непревзойденный_ADJ 0.48957574367523193
# красивый_ADJ 0.4886830449104309
# приятный_ADJ 0.48831671476364136
# привлекательный_ADJ 0.4735388159751892
# престижный_ADJ 0.46987858414649963
# шикарный_ADJ 0.46937504410743713
# первоклассный_ADJ 0.45550617575645447
# приличный_ADJ 0.4508042633533478
#
#
# плохой_ADJ
# плохо_ADV 0.6953262090682983
# дурной_ADJ 0.5840396881103516
# отвратительный_ADJ 0.5630063414573669
# хороший_ADJ 0.5595843195915222
# дерьмовый_ADJ 0.5529779195785522
# вообще_ADV 0.5458360910415649
# паршивый_ADJ 0.5451748371124268
# ...

# %%
# давайте попробую поставить ограничение на чр
for word in words:
    # есть ли слово в модели? Может быть, и нет
    if word in model4:
        print(word)
        # выдаем 10 ближайших соседей слова:
        for i in model4.most_similar(positive=[word], topn=20):
            # слово + коэффициент косинусной близости
            if i[0].endswith('_ADJ'):
                print(i[0], i[1])
        print('\n')
    else:
        # Увы!
        print(word + ' is not present in the model')
# Out:
# хороший_ADJ
# отличный_ADJ 0.7432949542999268
# неплохой_ADJ 0.6367652416229248
# превосходный_ADJ 0.604561448097229
# идеальный_ADJ 0.5773133039474487
# достойный_ADJ 0.5759782791137695
# отменный_ADJ 0.5750353336334229
# замечательный_ADJ 0.5604514479637146
# плохой_ADJ 0.5595842599868774
# прекрасный_ADJ 0.556372880935669
# удачный_ADJ 0.5306262969970703
# безупречный_ADJ 0.5232981443405151
# великолепный_ADJ 0.5031687617301941
# непревзойденный_ADJ 0.48957574367523193
# красивый_ADJ 0.4886830449104309
# приятный_ADJ 0.48831671476364136
# привлекательный_ADJ 0.4735388159751892
# престижный_ADJ 0.46987858414649963
# шикарный_ADJ 0.46937504410743713
# первоклассный_ADJ 0.45550617575645447
# приличный_ADJ 0.4508042633533478
#
#
# плохой_ADJ
# дурной_ADJ 0.5840396881103516
# отвратительный_ADJ 0.5630063414573669
# хороший_ADJ 0.5595843195915222
# дерьмовый_ADJ 0.5529779195785522
# паршивый_ADJ 0.5451748371124268
# отвратный_ADJ 0.5398692488670349
# нехороший_ADJ 0.5398507118225098
# ...

# %%
m = 'news_0_300_2.bin'
model5 = gensim.models.KeyedVectors.load_word2vec_format(m, binary=True)
# Out:
# 2017-03-21 20:50:50,936 : INFO : loading projection weights from news_0_300_2.bin
# 2017-03-21 20:50:56,004 : INFO : loaded (194058, 300) matrix from news_0_300_2.bin

# %%
model5.init_sims(replace=True)
# Out:
# 2017-03-21 20:51:09,912 : INFO : precomputing L2-norms of word weight vectors

# %%
for word in words:
    # есть ли слово в модели? Может быть, и нет
    if word in model5:
        print(word)
        # выдаем 10 ближайших соседей слова:
        for i in model5.most_similar(positive=[word], topn=20):
            # слово + коэффициент косинусной близости
            print(i[0], i[1])
        print('\n')
    else:
        # Увы!
        print(word + ' is not present in the model')
# Out:
# хороший_ADJ
# отличный_ADJ 0.582908034324646
# превосходный_ADJ 0.5551811456680298
# неплохой_ADJ 0.5318808555603027
# великолепный_ADJ 0.5074565410614014
# плохой_ADJ 0.4984378516674042
# отменный_ADJ 0.4888066053390503
# потрясающий_ADJ 0.4663708209991455
# добротный_ADJ 0.46553438901901245
# прекрасный_ADJ 0.4648173153400421
# недурной_ADJ 0.429069459438324
# посредственный_ADJ 0.4259202480316162
# фантастический_ADJ 0.42035430669784546
# блестящий_ADJ 0.40537089109420776
# импонировать_VERB 0.40268898010253906
# впечатляющий_ADJ 0.39969468116760254
# феноменальный_ADJ 0.3975653350353241
# классный_ADJ 0.3974508047103882
# многообещающий_ADJ 0.3957982659339905
# замечательный_ADJ 0.39460816979408264
# потрясать_VERB 0.39433911442756653
#
#
# плохой_ADJ
# хороший_ADJ 0.4984378218650818
# неважный_ADJ 0.48742133378982544
# неудовлетворительный_ADJ 0.4637413024902344
# ужасный_ADJ 0.4624607563018799
# отвратительный_ADJ 0.45640766620635986
# улучшаться_VERB 0.45477724075317383
# ...

# %%
# давайте попробую поставить ограничение на чр
for word in words:
    # есть ли слово в модели? Может быть, и нет
    if word in model5:
        print(word)
        # выдаем 10 ближайших соседей слова:
        for i in model5.most_similar(positive=[word], topn=20):
            # слово + коэффициент косинусной близости
            if i[0].endswith('_ADJ'):
                print(i[0], i[1])
        print('\n')
    else:
        # Увы!
        print(word + ' is not present in the model')
# Out:
# хороший_ADJ
# отличный_ADJ 0.582908034324646
# превосходный_ADJ 0.5551811456680298
# неплохой_ADJ 0.5318808555603027
# великолепный_ADJ 0.5074565410614014
# плохой_ADJ 0.4984378516674042
# отменный_ADJ 0.4888066053390503
# потрясающий_ADJ 0.4663708209991455
# добротный_ADJ 0.46553438901901245
# прекрасный_ADJ 0.4648173153400421
# недурной_ADJ 0.429069459438324
# посредственный_ADJ 0.4259202480316162
# фантастический_ADJ 0.42035430669784546
# блестящий_ADJ 0.40537089109420776
# впечатляющий_ADJ 0.39969468116760254
# феноменальный_ADJ 0.3975653350353241
# классный_ADJ 0.3974508047103882
# многообещающий_ADJ 0.3957982659339905
# замечательный_ADJ 0.39460816979408264
#
#
# плохой_ADJ
# хороший_ADJ 0.4984378218650818
# неважный_ADJ 0.48742133378982544
# неудовлетворительный_ADJ 0.4637413024902344
# ужасный_ADJ 0.4624607563018799
# отвратительный_ADJ 0.45640766620635986
# нервозный_ADJ 0.4539949297904968
# скверный_ADJ 0.4330900311470032
# пессимистический_ADJ 0.40654850006103516
# ...
